# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
import numpy as np
import os
from os import listdir
from IPython.display import Image
import pathlib
from pathlib import Path
from mpl_toolkits.axes_grid1 import ImageGrid
import numpy as np
from os import chdir
from PIL import Image
import matplotlib.gridspec as gridspec

# %%
{
    "tags": [
        "hide_input",
    ]
}
correct = ['blender_120_black', 'blender_15_white', 'blender_30_black',
       'blender_60_white', 'blender_165_black', 'blender_30_white',
       'blender_0_white', 'blender_15_black', 'blender_135_black',
       'blender_75_black', 'blender_150_white', 'blender_90_black',
       'blender_45_white', 'blender_105_black']
abstained = ['blender_105_white', 'blender_60_black', 'blender_75_white','blender_45_black']
incorrect = ['blender_60_black', 'blender_75_black', 'blender_60_white', 'blender_90_white', 'blender_75_white', 'blender_90_black']
print(correct)
print(f'correct: {len(correct)}')
print(f'abstained: {len(abstained)}')
print(f'incorrect: {len(incorrect)}')

correct_bird = ['blender_105_bird', 'blender_90_ybird', 'blender_75_ybird',
       'blender_30_bird', 'blender_60_ybird', 'blender_120_bird',
       'blender_105_ybird', 'blender_45_ybird', 'blender_15_bird',
       'blender_120_ybird', 'blender_30_ybird', 'blender_135_bird',
       'blender_0_bird', 'blender_135_ybird', 'blender_15_ybird',
       'blender_165_bird', 'blender_0_ybird', 'blender_150_bird',
       'blender_150_ybird', 'blender_165_ybird']

abstained_bird = ['blender_60_bird', 'blender_75_bird', 'blender_90_bird',
       'blender_45_bird', 'blender_105_bird']
# Out:
# ['blender_120_black', 'blender_15_white', 'blender_30_black', 'blender_60_white', 'blender_165_black', 'blender_30_white', 'blender_0_white', 'blender_15_black', 'blender_135_black', 'blender_75_black', 'blender_150_white', 'blender_90_black', 'blender_45_white', 'blender_105_black']
# correct: 14
# abstained: 4
# incorrect: 6

# %% [markdown]
# ### Correctly Classified Bike Images

# %%
{
    "tags": [
        "hide_input",
    ]
}
im_path = '/nvmescratch/mhull32/unrestricted-adversarial-examples/data_generation/augmented/bicycle'
chdir(im_path)
files = listdir(im_path)

handles = [f'{i}.jpg' for i in correct]
im = [i for i in files if i in handles]
images = [Image.open(f) for f in im]
num_rows = 5
num_cols = 4
fig = plt.figure(dpi=300)
gs = gridspec.GridSpec(num_rows, num_cols, hspace=0.15)

ax = [plt.subplot(gs[i]) for i in range(len(images))]

for i,im in enumerate(images):
    ax[i].imshow(im)
    ax[i].axis('off')
plt.subplots_adjust(wspace=-0.775)
plt.show()

# %% [markdown]
# ### No Prediction - Model Abstains
# #### (Low Confidence) 20% of Correct Predictions with Lowest Confidence

# %%
{
    "tags": [
        "hide_input",
    ]
}
im_path = '/nvmescratch/mhull32/unrestricted-adversarial-examples/data_generation/augmented/bicycle'
chdir(im_path)
files = listdir(im_path)

handles = [f'{i}.jpg' for i in abstained]
im = [i for i in files if i in handles]
images = [Image.open(f) for f in im]
num_rows = 5
num_cols = 4
fig = plt.figure(dpi=300)
gs = gridspec.GridSpec(num_rows, num_cols, hspace=0.15)

ax = [plt.subplot(gs[i]) for i in range(len(images))]

for i,im in enumerate(images):
    ax[i].imshow(im)
    ax[i].axis('off')
plt.subplots_adjust(wspace=-0.775)
plt.show()

# %% [markdown]
# ### Incorrectly Classified Images
# #### (Bikes classified as 'Bird')

# %%
{
    "tags": [
        "hide_input",
    ]
}
im_path = '/nvmescratch/mhull32/unrestricted-adversarial-examples/data_generation/augmented/bicycle'
chdir(im_path)
files = listdir(im_path)

handles = [f'{i}.jpg' for i in incorrect]
im = [i for i in files if i in handles]
images = [Image.open(f) for f in im]
num_rows = 5
num_cols = 4
fig = plt.figure(dpi=300)
gs = gridspec.GridSpec(num_rows, num_cols, hspace=0.15)
        
ax = [plt.subplot(gs[i]) for i in range(len(images))]

for i,im in enumerate(images):
    ax[i].imshow(im)
    ax[i].axis('off')
plt.subplots_adjust(wspace=-0.775)
plt.show()

# %% [markdown]
# ### Correctly Classified Bird Images

# %%
{
    "tags": [
        "hide_input",
    ]
}
im_path = '/nvmescratch/mhull32/unrestricted-adversarial-examples/data_generation/augmented/bird'
chdir(im_path)
files = listdir(im_path)

handles = [f'{i}.jpg' for i in correct_bird]
im = [i for i in files if i in handles]
images = [Image.open(f) for f in im]
num_rows = 5
num_cols = 4
fig = plt.figure(dpi=300)
gs = gridspec.GridSpec(num_rows, num_cols, hspace=0.15)

ax = [plt.subplot(gs[i]) for i in range(len(images))]

for i,im in enumerate(images):
    ax[i].imshow(im)
    ax[i].axis('off')
plt.subplots_adjust(wspace=-0.775)
plt.show()

# %% [markdown]
# ### No Prediction - Model Abstains
# #### (Low Confidence) 20% of Correct Predictions with Lowest Confidence

# %%
{
    "tags": [
        "hide_input",
    ]
}
im_path = '/nvmescratch/mhull32/unrestricted-adversarial-examples/data_generation/augmented/bird'
chdir(im_path)
files = listdir(im_path)

handles = [f'{i}.jpg' for i in abstained_bird]
im = [i for i in files if i in handles]
images = [Image.open(f) for f in im]
num_rows = 5
num_cols = 4
fig = plt.figure(dpi=300)
gs = gridspec.GridSpec(num_rows, num_cols, hspace=0.15)

ax = [plt.subplot(gs[i]) for i in range(len(images))]

for i,im in enumerate(images):
    ax[i].imshow(im)
    ax[i].axis('off')
plt.subplots_adjust(wspace=-0.775)
plt.show()
